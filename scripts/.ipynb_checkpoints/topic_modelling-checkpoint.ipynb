# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import spacy
import pyLDAvis.gensim_models
pyLDAvis.enable_notebook()# Visualise inside a notebook
import en_core_web_md
from gensim.corpora.dictionary import Dictionary
from gensim.models import LdaMulticore
from gensim.models import CoherenceModel

# %%
lang = "en"

# %%
df_comb = pd.read_excel("../files/input/combined_data.xlsx")

# %%
df_comb.head()
# Out:
#               person                                            content
# 0     George Clooney  George Timothy Clooney (born May 6, 1961) is a...
# 1     Shah Rukh Khan  Shah Rukh Khan (pronounced [ˈʃɑːɦɾʊx xɑːn]; bo...
# 2  Leonardo DiCaprio  Leonardo Wilhelm DiCaprio (; Italian: [diˈkaːp...
# 3         Will Smith  Willard Carroll  Smith II (born September 25, ...
# 4       Kamal Haasan  Kamal Haasan (born 7 November 1954) is an Indi...

# %%
## lang detect python

# %%
from langdetect import detect, DetectorFactory
DetectorFactory.seed = 0

df_comb["actual_lang"] = df_comb["content"].apply(detect)

# %%
## add this comment to code

a = df_comb[df_comb["actual_lang"]=="en"]
a[a.duplicated('person')]
# Out:
#              person                                            content  \
# 55     Kamal Haasan  Kamal Haasan (Ramanathapuram, 7 novembre 1954)...
# 78  James Patterson  James Patterson (Newburgh, 22 marzo 1947) è un...
#
#    actual_lang
# 55          en
# 78          en

# %%
df_comb.actual_lang.value_counts()
# Out:
# en    53
# ru    51
# it    49
# Name: actual_lang, dtype: int64

# %%
## filter to required lang

# %%
df = df_comb[df_comb["actual_lang"] == str(lang)].reset_index(drop=True)

# %%
df.head()
# Out:
#               person                                            content  \
# 0     George Clooney  George Timothy Clooney (born May 6, 1961) is a...
# 1     Shah Rukh Khan  Shah Rukh Khan (pronounced [ˈʃɑːɦɾʊx xɑːn]; bo...
# 2  Leonardo DiCaprio  Leonardo Wilhelm DiCaprio (; Italian: [diˈkaːp...
# 3         Will Smith  Willard Carroll  Smith II (born September 25, ...
# 4       Kamal Haasan  Kamal Haasan (born 7 November 1954) is an Indi...
#
#   actual_lang
# 0          en
# 1          en
# 2          en
# 3          en
# 4          en

# %%
import warnings
warnings.filterwarnings('ignore')
lang_models = {"en": spacy.load("en_core_web_md"), "it": spacy.load("it_core_news_md"), "ru": spacy.load("ru_core_news_md")}

# %%
# Our spaCy model:
nlp = lang_models[str(lang)]
# Tags I want to remove from the text
removal= ['ADV','PRON','CCONJ','PUNCT','PART','DET','ADP','SPACE', 'NUM', 'SYM']
tokens = []
for summary in nlp.pipe(df['content']):
    proj_tok = [token.lemma_.lower() for token in summary if token.pos_ not in removal and not token.is_stop and token.is_alpha]
    tokens.append(proj_tok)

# %%
df['tokens'] = tokens
df['tokens'][:3]

# %%
# I will apply the Dictionary Object from Gensim, which maps each word to their unique ID:
dictionary = Dictionary(df['tokens'])

# %%
print(dictionary.token2id)

# %%
dictionary.filter_extremes(no_below=5, no_above=0.5, keep_n=1000)

# %%
corpus = [dictionary.doc2bow(doc) for doc in df['tokens']]

# %%
# lda_model = LdaMulticore(corpus=corpus, id2word=dictionary, iterations=50, num_topics=10, workers = 4, passes=10)

# %%
topics = []
score = []
for i in range(1,10,1):
    print("Running iteration number " + str(i))
    lda_model = LdaMulticore(corpus=corpus, id2word=dictionary, iterations=10, num_topics=i, workers = 4, passes=10, random_state=100)
    cm = CoherenceModel(model=lda_model, texts = df['tokens'], corpus=corpus, dictionary=dictionary, coherence='c_v')
    topics.append(i)
    score.append(cm.get_coherence())
fig, ax = plt.subplots(nrows=1, ncols=1)
plt.plot(topics, score)
plt.xlabel('Number of Topics')
plt.ylabel('Coherence Score')
plt.title('Coherence Score Analysis for ' + str(lang))
fig.patch.set_facecolor('white')
plt.show()
fig.savefig("../files/output/" + str(lang) + "/coherence_score_" + str(lang) + ".png", bbox_inches='tight')

# %%
num_topics = topics[score.index(max(score))]
num_topics

# %%
print("Number of topics with highest coherence score for " + str(lang) + " model is: " + str(num_topics))
# Out:
# Number of topics with highest coherence score for it model is: 6

# %%
lda_model = LdaMulticore(corpus=corpus, id2word=dictionary, iterations=100, num_topics=num_topics, workers = 4, passes=100)

# %%
lda_model.print_topics(-1)
# Out:
# [(0,
#   '0.054*"album" + 0.044*"singolo" + 0.023*"brano" + 0.022*"canzone" + 0.021*"artista" + 0.020*"cantante" + 0.017*"video" + 0.015*"billboard" + 0.015*"classifica" + 0.013*"you"'),
#  (1,
#   '0.057*"regia" + 0.044*"attore" + 0.020*"interpretare" + 0.019*"miglior" + 0.016*"oscar" + 0.015*"tv" + 0.014*"recitare" + 0.012*"candidatura" + 0.012*"regista" + 0.011*"dirigere"'),
#  (2,
#   '0.064*"romanzo" + 0.048*"libro" + 0.029*"scrittore" + 0.024*"brown" + 0.024*"autore" + 0.023*"opera" + 0.019*"isbn" + 0.013*"raccolta" + 0.013*"britannico" + 0.012*"editore"'),
#  (3,
#   '0.018*"clinton" + 0.017*"obama" + 0.013*"partito" + 0.010*"elezione" + 0.010*"politico" + 0.008*"democratico" + 0.008*"campagna" + 0.007*"bill" + 0.007*"legge" + 0.007*"società"'),
#  (4,
#   '0.045*"finale" + 0.030*"stagione" + 0.022*"vittoria" + 0.021*"partita" + 0.021*"oro" + 0.021*"record" + 0.020*"m" + 0.020*"battere" + 0.019*"open" + 0.015*"set"'),
#  (5,
#   '0.064*"regia" + 0.037*"attore" + 0.023*"rock" + 0.019*"candidatura" + 0.018*"it" + 0.018*"king" + 0.017*"miglior" + 0.016*"smith" + 0.014*"tv" + 0.009*"tom"')]

# %%
# set sort_topics to be False to ensure same order as gensim model
# thing to take note of is that gensim starts from 0, pyldavis starts from 1
lda_display = pyLDAvis.gensim_models.prepare(lda_model, corpus, dictionary, sort_topics=False)
pyLDAvis.save_html(lda_display, "../files/output/" + str(lang) + "/lda_" + str(lang) + ".html")

# %%
df.head()
# Out:
#               person                                            content  \
# 0     George Clooney  George Timothy Clooney (Lexington, 6 maggio 19...
# 1     Shah Rukh Khan  Shah Rukh Khan, all'anagrafe Shahrukh Khan, co...
# 2  Leonardo DiCaprio  Leonardo Wilhelm DiCaprio (Los Angeles, 11 nov...
# 3         Will Smith  Will Smith, all'anagrafe Willard Carroll Smith...
# 4         Tom Cruise  Thomas Cruise Mapother IV, noto semplicemente ...
#
#   actual_lang                                             tokens
# 0          it  [george, timothy, clooney, lexington, maggio, ...
# 1          it  [shah, rukh, khan, anagrafe, shahrukh, khan, c...
# 2          it  [leonardo, wilhelm, dicaprio, los, angeles, no...
# 3          it  [will, smith, anagrafe, willard, carroll, smit...
# 4          it  [thomas, cruise, mapother, iv, noto, tom, crui...

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=df['tokens']):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
#     contents = pd.Series(texts)
#     sent_topics_df = pd.concat([sent_topics_df, df], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=df['tokens'])

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index(drop=True)
df_dominant_topic.columns = ['Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords']
df_dominant_topic = pd.concat([df,df_dominant_topic], axis=1)
df_dominant_topic
# Out:
#                person                                            content  \
# 0      George Clooney  George Timothy Clooney (Lexington, 6 maggio 19...
# 1      Shah Rukh Khan  Shah Rukh Khan, all'anagrafe Shahrukh Khan, co...
# 2   Leonardo DiCaprio  Leonardo Wilhelm DiCaprio (Los Angeles, 11 nov...
# 3          Will Smith  Will Smith, all'anagrafe Willard Carroll Smith...
# 4          Tom Cruise  Thomas Cruise Mapother IV, noto semplicemente ...
# 5      Dwayne Johnson  Dwayne Douglas Johnson, conosciuto anche come ...
# 6           Brad Pitt  William Bradley Pitt, detto Brad (Shawnee, 18 ...
# 7         Johnny Depp  Johnny Depp, all'anagrafe John Christopher Dep...
# 8      Morgan Freeman  Morgan Freeman (Memphis, 1º giugno 1937) è un ...
# 9          Ed Sheeran  Edward Christopher Sheeran (Halifax, 17 febbra...
# 10       A. R. Rahman  Allahrakka Rahman, nome d'arte di A. S. Dileep...
# 11         Bruno Mars  Bruno Mars, pseudonimo di Peter Gene Hernandez...
# 12       Taylor Swift  Taylor Alison Swift (West Reading, 13 dicembre...
# 13             Eminem  Eminem, pseudonimo di Marshall Bruce Mathers I...
# 14            Shakira  Shakira Isabel Mebarak Ripoll, conosciuta come...
# 15     Ellie Goulding  Elena Jane Goulding, nota professionalmente co...
# 16    Michael Jackson  Michael Joseph Jackson (Gary, 29 agosto 1958 –...
# 17       Selena Gomez  Selena Marie Gomez (IPA: [səˈliːnə ˈɡoʊmɛz]; G...
# 18       Lionel Messi  Lionel Andrés Messi Cuccittini, detto Leo (pro...
# 19  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro, meglio no...
# 20       Rafael Nadal  Rafael Nadal Parera, detto Rafa (Manacor, 3 gi...
# 21         Usain Bolt  Usain St. Leo Bolt (Sherwood Content, 21 agost...
# 22      Stephen Curry  Wardell Stephen Curry II, detto Steph (Akron, ...
# 23      Roger Federer  Roger Federer (Basilea, 8 agosto 1981) è un te...
# 24        Virat Kohli  Virat Kohli (Delhi, 5 novembre 1988) è un cric...
# 25    Serena Williams  Serena Jameka Williams (Saginaw, 26 settembre ...
# 26       Stephen King  Stephen Edwin King (IPA: [ˈstiːvən ˈɛdwɪn ˈkɪŋ...
# 27      J. K. Rowling  Joanne Rowling (pron. [joæn roʊlɪŋ]; Yate, 31 ...
# 28          Dan Brown  Daniel Gerhard Brown conosciuto come Dan Brown...
# 29    Agatha Christie  Dame Agatha Christie, nome completo Agatha Mar...
# 30        Ken Follett  Ken Follett, all'anagrafe Kenneth Martin Folle...
# 31        Neil Gaiman  Neil Gaiman, all'anagrafe Neil Richard MacKinn...
# 32       John Grisham  John Ray Grisham Jr. (Jonesboro, 8 febbraio 19...
# 33       Nora Roberts  Nora Roberts, all'anagrafe Eleanor Marie Rober...
# 34      Arundhati Roy  Arundhati Roy (in malayalam: അരുന്ധതി റോയ്, in...
# 35    Mark Zuckerberg  Mark Elliot Zuckerberg (IPA: [mɑɹk ˈɛliət ˈzʌk...
# 36         Jeff Bezos  Jeffrey Preston Bezos, nato Jorgensen (Albuque...
# 37         Bill Gates  Bill Gates, all'anagrafe William Henry Gates I...
# 38         Larry Page  Lawrence Page, detto Larry (East Lansing, 26 m...
# 39           Tim Cook  Timothy Donald Cook, più noto come Tim Cook (M...
# 40          Elon Musk  Elon Reeve Musk (Pretoria, 28 giugno 1971) è u...
# 41     Warren Buffett  Warren Edward Buffett (Omaha, 30 agosto 1930) ...
# 42         Xi Jinping  Xi Jinping (習近平T, 习近平S, Xí JìnpíngP, pronuncia...
# 43     Vladimir Putin  Vladimir Vladimirovič Putin (in russo: Влади́м...
# 44       Donald Trump  Donald John Trump (AFI: [ˈdɑnəɫd ˈʤɑn ˈtʰɹʌmp]...
# 45       Barack Obama  Barack Hussein Obama II (/bəˈrɑːk hʊˈseɪn oʊˈb...
# 46      David Cameron  David William Donald Cameron (Londra, 9 ottobr...
# 47    Hillary Clinton  Hillary Diane Clinton, nata Rodham (pronuncia ...
# 48       Bill Clinton  William Jefferson Clinton, nato con il nome di...
#
#    actual_lang                                             tokens  \
# 0           it  [george, timothy, clooney, lexington, maggio, ...
# 1           it  [shah, rukh, khan, anagrafe, shahrukh, khan, c...
# 2           it  [leonardo, wilhelm, dicaprio, los, angeles, no...
# 3           it  [will, smith, anagrafe, willard, carroll, smit...
# 4           it  [thomas, cruise, mapother, iv, noto, tom, crui...
# 5           it  [dwayne, douglas, johnson, conoscere, rock, ha...
# 6           it  [william, bradley, pitt, brad, shawnee, dicemb...
# 7           it  [johnny, depp, anagrafe, john, christopher, de...
# 8           it  [morgan, freeman, memphis, giugno, attore, pro...
# 9           it  [edward, christopher, sheeran, halifax, febbra...
# 10          it  [allahrakka, rahman, nome, arte, dileep, kumar...
# 11          it  [bruno, mars, pseudonimo, peter, gene, hernand...
# 12          it  [taylor, alison, swift, west, reading, dicembr...
# 13          it  [eminem, pseudonimo, marshall, bruce, mathers,...
# 14          it  [shakira, isabel, mebarak, ripoll, conoscere, ...
# 15          it  [elena, jane, goulding, notare, ellie, gouldin...
# 16          it  [michael, joseph, jackson, gary, agosto, los, ...
# 17          it  [selena, marie, gomez, ipa, səˈliːnə, ˈɡoʊmɛzo...
# 18          it  [lionel, andrés, messi, cuccittini, leo, pronu...
# 19          it  [cristiano, ronaldo, dosre, santos, aveiro, no...
# 20          it  [rafael, nadal, parera, rafa, manacor, giugno,...
# 21          it  [usain, leo, bolt, sherwood, content, agosto, ...
# 22          it  [wardell, stephen, curry, ii, steph, akron, ma...
# 23          it  [roger, federer, basilea, agosto, tennista, sv...
# 24          it  [virat, kohli, delhi, novembre, crickettista, ...
# 25          it  [serena, jameka, williams, saginaw, settembre,...
# 26          it  [stephen, edwin, king, ipa, ˈstiːvən, ˈɛdwɪn, ...
# 27          it  [joanne, rowling, pron, joæn, roʊlɪŋ, yate, lu...
# 28          it  [daniel, gerhard, brown, conoscere, dan, brown...
# 29          it  [dame, agatha, christie, nome, completo, agath...
# 30          it  [ken, follett, anagrafe, kenneth, martin, foll...
# 31          it  [neil, gaiman, anagrafe, neil, richard, mackin...
# 32          it  [john, ray, grisham, jonesboro, febbraio, poli...
# 33          it  [nora, roberts, anagrafe, eleanor, marie, robe...
# 34          it  [arundhati, roy, malayalam, devanagario, shill...
# 35          it  [mark, elliot, zuckerberg, ipa, mɑɹk, ˈɛliət, ...
# 36          it  [jeffrey, preston, bezos, nascere, jorgensen, ...
# 37          it  [bill, gates, anagrafe, william, henry, gates,...
# 38          it  [lawrence, page, larry, east, lansing, marzo, ...
# 39          it  [timothy, donald, cook, noto, tim, cook, mobil...
# 40          it  [elon, reeve, musk, pretoria, giugno, imprendi...
# 41          it  [warren, edward, buffett, omaha, agosto, impre...
# 42          it  [xi, jinping, 習近平t, 习近平s, xí, pronunciare, pec...
# 43          it  [vladimir, vladimirovič, putin, russo, ipa, vl...
# 44          it  [donald, john, trump, afi, ˈdɑnəɫd, ˈʤɑn, ˈtʰɹ...
# 45          it  [barack, hussein, obama, ii, hʊˈseɪn, honolulu...
# 46          it  [david, william, donald, cameron, londra, otto...
# 47          it  [hillary, diane, clinton, nato, rodham, pronun...
# 48          it  [william, jefferson, clinton, nascere, nome, w...
#
#     Dominant_Topic  Topic_Perc_Contrib  \
# 0                1              0.9992
# 1                5              0.9974
# 2                1              0.7735
# 3                5              0.8898
# 4                5              0.6583
# 5                5              0.6267
# 6                1              0.9990
# 7                1              0.4817
# 8                5              0.9828
# 9                0              0.8005
# 10               5              0.9921
# 11               0              0.9380
# 12               0              0.9992
# 13               0              0.7910
# 14               0              0.9924
# 15               0              0.8291
# 16               0              0.9268
# 17               0              0.8117
# 18               4              0.9989
# 19               4              0.8517
# 20               4              0.9989
# 21               4              0.9473
# 22               4              0.9989
# 23               4              0.9989
# 24               5              0.9357
# 25               4              0.9990
# 26               5              0.5293
# 27               2              0.9990
# 28               2              0.5613
# 29               3              0.6047
# 30               5              0.3632
# 31               5              0.5686
# 32               5              0.4351
# 33               5              0.4070
# 34               3              0.7656
# 35               3              0.9065
# 36               3              0.9123
# 37               3              0.9522
# 38               3              0.9013
# 39               3              0.9871
# 40               3              0.8695
# 41               3              0.9580
# 42               3              0.9980
# 43               3              0.9989
# 44               3              0.9331
# 45               3              0.9991
# 46               3              0.9562
# 47               3              0.9799
# 48               3              0.9991
#
#                                              Keywords
# 0   regia, attore, interpretare, miglior, oscar, t...
# 1   regia, attore, rock, candidatura, it, king, mi...
# 2   regia, attore, interpretare, miglior, oscar, t...
# 3   regia, attore, rock, candidatura, it, king, mi...
# 4   regia, attore, rock, candidatura, it, king, mi...
# 5   regia, attore, rock, candidatura, it, king, mi...
# 6   regia, attore, interpretare, miglior, oscar, t...
# 7   regia, attore, interpretare, miglior, oscar, t...
# 8   regia, attore, rock, candidatura, it, king, mi...
# 9   album, singolo, brano, canzone, artista, canta...
# 10  regia, attore, rock, candidatura, it, king, mi...
# 11  album, singolo, brano, canzone, artista, canta...
# 12  album, singolo, brano, canzone, artista, canta...
# 13  album, singolo, brano, canzone, artista, canta...
# 14  album, singolo, brano, canzone, artista, canta...
# 15  album, singolo, brano, canzone, artista, canta...
# 16  album, singolo, brano, canzone, artista, canta...
# 17  album, singolo, brano, canzone, artista, canta...
# 18  finale, stagione, vittoria, partita, oro, reco...
# 19  finale, stagione, vittoria, partita, oro, reco...
# 20  finale, stagione, vittoria, partita, oro, reco...
# 21  finale, stagione, vittoria, partita, oro, reco...
# 22  finale, stagione, vittoria, partita, oro, reco...
# 23  finale, stagione, vittoria, partita, oro, reco...
# 24  regia, attore, rock, candidatura, it, king, mi...
# 25  finale, stagione, vittoria, partita, oro, reco...
# 26  regia, attore, rock, candidatura, it, king, mi...
# 27  romanzo, libro, scrittore, brown, autore, oper...
# 28  romanzo, libro, scrittore, brown, autore, oper...
# 29  clinton, obama, partito, elezione, politico, d...
# 30  regia, attore, rock, candidatura, it, king, mi...
# 31  regia, attore, rock, candidatura, it, king, mi...
# 32  regia, attore, rock, candidatura, it, king, mi...
# 33  regia, attore, rock, candidatura, it, king, mi...
# 34  clinton, obama, partito, elezione, politico, d...
# 35  clinton, obama, partito, elezione, politico, d...
# 36  clinton, obama, partito, elezione, politico, d...
# 37  clinton, obama, partito, elezione, politico, d...
# 38  clinton, obama, partito, elezione, politico, d...
# 39  clinton, obama, partito, elezione, politico, d...
# 40  clinton, obama, partito, elezione, politico, d...
# 41  clinton, obama, partito, elezione, politico, d...
# 42  clinton, obama, partito, elezione, politico, d...
# 43  clinton, obama, partito, elezione, politico, d...
# 44  clinton, obama, partito, elezione, politico, d...
# 45  clinton, obama, partito, elezione, politico, d...
# 46  clinton, obama, partito, elezione, politico, d...
# 47  clinton, obama, partito, elezione, politico, d...
# 48  clinton, obama, partito, elezione, politico, d...

# %%
writer = pd.ExcelWriter('../files/output/' +str(lang) + '/topic_modelling_output_' + str(lang) + '.xlsx' , engine='xlsxwriter')
workbook = writer.book
workbook.formats[0].set_font_size(12)
df_dominant_topic.to_excel(writer, sheet_name = 'Output', index=False)

for idx, col in enumerate(df_dominant_topic):  # loop through all columns
    series = df_dominant_topic[col]
    max_len = 20
    writer.sheets['Output'].set_column(idx, idx, max_len)  # set column width
    
writer.close()
# Out:
# /Users/bhaveshchainani/virtualenv/proofpoint_code/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/bhaveshchainani/virtualenv/proofpoint_code/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/bhaveshchainani/virtualenv/proofpoint_code/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/bhaveshchainani/virtualenv/proofpoint_code/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/bhaveshchainani/virtualenv/proofpoint_code/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/bhaveshchainani/virtualenv/proofpoint_code/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/bhaveshchainani/virtualenv/proofpoint_code/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/bhaveshchainani/virtualenv/proofpoint_code/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
